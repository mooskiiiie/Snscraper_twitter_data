# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Creating list to append tweet data
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('tallano gold since:2021-10-01 until:2022-1-25').get_items()):
    if i>10000:
        break
    tweets_list.append([tweet.date, tweet.url, tweet.id, tweet.content, tweet.user.username, 
                         tweet.user.description, tweet.user.verified, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    
# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'URL', 'Tweet Id', 'Text', 'Username', 'Bio', 'Verified', 'Retweeted', 'Quoted', 'Mentioned Users'])

# %%
tweets_df
# Out:
#                       Datetime  \
# 0    2022-01-24 23:51:20+00:00
# 1    2022-01-24 23:50:43+00:00
# 2    2022-01-24 23:45:52+00:00
# 3    2022-01-24 23:43:10+00:00
# 4    2022-01-24 23:42:16+00:00
# ...                        ...
# 6420 2021-10-04 15:29:09+00:00
# 6421 2021-10-04 11:26:14+00:00
# 6422 2021-10-04 11:08:06+00:00
# 6423 2021-10-04 10:49:45+00:00
# 6424 2021-10-04 05:24:29+00:00
#
#                                                     URL             Tweet Id  \
# 0     https://twitter.com/JPRamir67189503/status/148...  1485762170499391488
# 1     https://twitter.com/jpgwapo31/status/148576201...  1485762014479851521
# 2     https://twitter.com/rmrtnez_/status/1485760794...  1485760794533175298
# 3     https://twitter.com/adazolram/status/148576011...  1485760117941276672
# 4     https://twitter.com/HabaloRita/status/14857598...  1485759888143777793
# ...                                                 ...                  ...
# ...
